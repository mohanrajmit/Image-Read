# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Image-Read/blob/master/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import argparse
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/mohanrajmit/Image-Read.git
# Out:
# fatal: destination path 'Image-Read' already exists and is not an empty directory.

# %%
label_name=["cats","dogs","panda"]

# %%
def load():
		# initialize the list of features and labels
		data = []
		labels = []

		# loop over the input images
		for (i, imagePath) in enumerate(imagePaths):
			# load the image and extract the class label assuming
			# that our path has the following format:
			# /path/to/dataset/{class}/{image}.jpg
			image = cv2.imread(imagePath)
			label = imagePath.split("/")[-2]
			#label = imagePath.split(os.path.sep)[-2]
			image = cv2.resize(image, (32, 32),interpolation=cv2.INTER_AREA)
			
			# treat our processed image as a "feature vector"
			# by updating the data list followed by the labels
			data.append(image)
			labels.append(label)

			# show an update every `verbose` images
			#if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
				#print("[INFO] processed {}/{}".format(i + 1,
					#len(imagePaths)))

		# return a tuple of the data and labels
		return (np.array(data), np.array(labels))

# %%
# grab the list of images that we'll be describing
print("[INFO] loading images...")
imagePaths = list(paths.list_images("Image-Read/animals"))
print(imagePaths)

# initialize the image preprocessor, load the dataset from disk,
# and reshape the data matrix
#sp = SimplePreprocessor(32, 32)
#sdl = SimpleDatasetLoader(preprocessors=[sp])
(data, labels) = load()

data = data.reshape((data.shape[0], 3072))


# encode the labels as integers
le = LabelEncoder()
labels = le.fit_transform(labels)

# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.25, random_state=42)
# Out:
# [INFO] loading images...
# ['Image-Read/animals/panda/panda_00290.jpg', 'Image-Read/animals/panda/panda_00210.jpg', 'Image-Read/animals/panda/panda_00565.jpg', 'Image-Read/animals/panda/panda_00410.jpg', 'Image-Read/animals/panda/panda_00380.jpg', 'Image-Read/animals/panda/panda_00330.jpg', 'Image-Read/animals/panda/panda_00961.jpg', 'Image-Read/animals/panda/panda_00066.jpg', 'Image-Read/animals/panda/panda_00262.jpg', 'Image-Read/animals/panda/panda_00709.jpg', 'Image-Read/animals/panda/panda_00907.jpg', 'Image-Read/animals/panda/panda_00259.jpg', 'Image-Read/animals/panda/panda_00600.jpg', 'Image-Read/animals/panda/panda_00278.jpg', 'Image-Read/animals/panda/panda_00647.jpg', 'Image-Read/animals/panda/panda_00204.jpg', 'Image-Read/animals/panda/panda_00691.jpg', 'Image-Read/animals/panda/panda_00260.jpg', 'Image-Read/animals/panda/panda_00043.jpg', 'Image-Read/animals/panda/panda_00272.jpg', 'Image-Read/animals/panda/panda_00870.jpg', 'Image-Read/animals/panda/panda_00245.jpg', 'Image-Read/animals/panda/panda_00004.jpg', 'Image-Read/animals/panda/panda_00964.jpg', 'Image-Read/animals/panda/panda_00697.jpg', 'Image-Read/animals/panda/panda_00389.jpg', 'Image-Read/animals/panda/panda_00118.jpg', 'Image-Read/animals/panda/panda_00372.jpg', 'Image-Read/animals/panda/panda_00094.jpg', 'Image-Read/animals/panda/panda_00797.jpg', 'Image-Read/animals/panda/panda_00631.jpg', 'Image-Read/animals/panda/panda_00291.jpg', 'Image-Read/animals/panda/panda_00119.jpg', 'Image-Read/animals/panda/panda_00486.jpg', 'Image-Read/animals/panda/panda_00662.jpg', 'Image-Read/animals/panda/panda_00407.jpg', 'Image-Read/animals/panda/panda_00149.jpg', 'Image-Read/animals/panda/panda_00993.jpg', 'Image-Read/animals/panda