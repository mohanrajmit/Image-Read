# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Image-Read/blob/master/thresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
image = cv2.imread("/content/license_plate.png")

# %%
image.shape
# Out:
# (90, 400, 3)

# %%
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
plt.imshow(image)

# %%
gray =cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (90, 400)

# %%
blurred = cv2.GaussianBlur(gray, (7, 7), 0)

# %%
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=400x90>

# %%
(T, threshInv) = cv2.threshold(blurred, 105, 255, cv2.THRESH_BINARY)

# %%
cv2_imshow(threshInv)
# Out:
# <PIL.Image.Image image mode=L size=400x90>

# %%
(T, threshInv_otsu) = cv2.threshold(blurred, 0, 255,
	cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# %%
T
# Out:
# 105.0

# %%
cv2_imshow(threshInv_otsu)
# Out:
# <PIL.Image.Image image mode=L size=400x90>

# %%
thresh_adap = cv2.adaptiveThreshold(blurred, 255,
	cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 25, 15)

# %%
cv2_imshow(thresh_adap)
# Out:
# <PIL.Image.Image image mode=L size=400x90>
