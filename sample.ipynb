# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Image-Read/blob/master/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.1.2'

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/content/1.jpg")

# %%
plt.imshow(image)
