# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Image-Read/blob/master/image_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 4.1.2

# %%
# !git clone https://github.com/mohanrajmit/Image-Read.git
# Out:
# Cloning into 'Image-Read'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 3065 (delta 4), reused 0 (delta 0), pack-reused 3053
# Receiving objects: 100% (3065/3065), 190.64 MiB | 48.31 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
image = cv2.imread("/content/Image-Read/1.jpg")
h=image.shape[0]
w=image.shape[1]
c=image.shape[2]

print(h,w,c)
# Out:
# 183 275 3

# %%
(b,g,r) = image[10,20]
print(b,g,r)
# Out:
# 19 24 23

# %%
plt.imshow(image)
