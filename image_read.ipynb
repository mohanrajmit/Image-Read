# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Image-Read/blob/master/image_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.9.2

# %%
# !git clone https://github.com/mohanrajmit/Image-Read.git
# Out:
# Cloning into 'Image-Read'...
# remote: Enumerating objects: 3107, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 3107 (delta 35), reused 26 (delta 23), pack-reused 3061
# Receiving objects: 100% (3107/3107), 191.48 MiB | 36.46 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Updating files: 100% (3016/3016), done.

# %%
image = cv2.imread("/content/Image-Read/1.jpg")
h=image.shape[0]
w=image.shape[1]
c=image.shape[2]

print(h,w,c)
# Out:
# 720 1280 3

# %%
(b,g,r) = image[10,20]
print(b,g,r)
# Out:
# 126 129 133

# %%
plt.imshow(image)
