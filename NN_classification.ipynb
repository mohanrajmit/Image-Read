# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Image-Read/blob/master/NN_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.4.0'

# %%
# !pip install opencv-python==4.4.0.46
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 MB 18.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.7.0.72
#     Uninstalling opencv-python-4.7.0.72:
#       Successfully uninstalled opencv-python-4.7.0.72
# ...

# %%
image = cv2.imread("/content/drive/MyDrive/2.jpg")

# %%
image.shape
# Out:
# (121, 182, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
# !git clone https://github.com/mohanrajmit/AGE_ESTIMATION.git
# Out:
# Cloning into 'AGE_ESTIMATION'...
# remote: Enumerating objects: 45776, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 45776 (delta 12), reused 0 (delta 0), pack-reused 45743
# Receiving objects: 100% (45776/45776), 131.60 MiB | 30.46 MiB/s, done.
# Resolving deltas: 100% (9745/9745), done.
# Updating files: 100% (26557/26557), done.

# %%
import pandas as pd

# %%
# !git clone https://github.com/mohanrajmit/Image-Read.git
# Out:
# Cloning into 'Image-Read'...
# remote: Enumerating objects: 3110, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 3110 (delta 36), reused 26 (delta 23), pack-reused 3061
# Receiving objects: 100% (3110/3110), 191.55 MiB | 46.37 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
data = pd.read_csv("/content/Image-Read/pima-indians-diabetes.csv",header=None)

# %%
data.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       768 non-null    int64
#  1   1       768 non-null    int64
#  2   2       768 non-null    int64
#  3   3       768 non-null    int64
#  4   4       768 non-null    int64
#  5   5       768 non-null    float64
#  6   6       768 non-null    float64
#  7   7       768 non-null    int64
#  8   8       768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.shape
# Out:
# (768, 9)

# %%
data.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#                 6           7           8
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
data.tail()
# Out:
#       0    1   2   3    4     5      6   7  8
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0

# %%
len(data[data[8]==0])
# Out:
# 500

# %%
len(data[data[8]==1])
# Out:
# 268

# %%
y= data[8]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: 8, Length: 768, dtype: int64

# %%
x = data.drop(8,axis=1)

# %%
x.head()
# Out:
#    0    1   2   3    4     5      6   7
# 0  6  148  72  35    0  33.6  0.627  50
# 1  1   85  66  29    0  26.6  0.351  31
# 2  8  183  64   0    0  23.3  0.672  32
# 3  1   89  66  23   94  28.1  0.167  21
# 4  0  137  40  35  168  43.1  2.288  33

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.models import Sequential

# %%
model = Sequential()

# %%
model.add(Dense(12,input_dim=8,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 12)                108
#
#  dense_5 (Dense)             (None, 10)                130
#
#  dense_6 (Dense)             (None, 1)                 11
#
#  dense_7 (Dense)             (None, 12)                24
#
#  dense_8 (Dense)             (None, 10)                130
#
#  dense_9 (Dense)             (None, 8)                 88
#
#  dense_10 (Dense)            (None, 1)                 9
#
# ...
# Total params: 500
# Trainable params: 500
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.fit(x,y,epochs=400,batch_size=40)
# Out:
# Epoch 1/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4441 - accuracy: 0.7943
# Epoch 2/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4858 - accuracy: 0.7708
# Epoch 3/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4493 - accuracy: 0.7812
# Epoch 4/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4386 - accuracy: 0.7891
# Epoch 5/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4388 - accuracy: 0.7943
# Epoch 6/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4445 - accuracy: 0.7852
# Epoch 7/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4426 - accuracy: 0.7995
# Epoch 8/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4398 - accuracy: 0.7969
# Epoch 9/400
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4396 - accuracy: 0.7917
# Epoch 10/400
# ...

# %%
model.evaluate(x, y)
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4045 - accuracy: 0.8060
# [0.4044859707355499, 0.8059895634651184]
