# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Image-Read/blob/master/linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import numpy as np
import cv2

# %%
# !git clone https://github.com/mohanrajmit/Image-Read.git
# Out:
# Cloning into 'Image-Read'...
# remote: Enumerating objects: 3137, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 3137 (delta 48), reused 26 (delta 23), pack-reused 3061
# Receiving objects: 100% (3137/3137), 193.05 MiB | 28.41 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
# initialize the class labels and set the seed of the pseudorandom
# number generator so we can reproduce our results
labels = ["dog", "cat", "panda"]
np.random.seed(1)

# %%
# randomly initialize our weight matrix and bias vector -- in a
# *real* training and classification task, these parameters would
# be *learned* by our model, but for the sake of this example,
# let's use random values
W = np.random.randn(3, 3072)
b = np.random.randn(3)

# %%
# load our example image, resize it, and then flatten it into our
# "feature vector" representation
orig = cv2.imread("/content/Image-Read/beagle.png")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(orig)

# %%
orig.shape
# Out:
# (336, 500, 3)

# %%
image = cv2.resize(orig, (32, 32))

# %%
image.shape
# Out:
# (32, 32, 3)

# %%
vector  = image.flatten()

# %%
len(vector)
# Out:
# 3072

# %%
# compute the output scores by taking the dot product between the
# weight matrix and image pixels, followed by adding in the bias
scores = W.dot(vector) + b

# %%
scores
# Out:
# array([ 7963.92759169, -2930.99452794,  3362.47036823])

# %%
# loop over the scores + labels and display them
for (label, score) in zip(labels, scores):
	print("[INFO] {}: {:.2f}".format(label, score))
# Out:
# [INFO] dog: 7963.93
# [INFO] cat: -2930.99
# [INFO] panda: 3362.47

# %%
# draw the label with the highest score on the image as our
# prediction
cv2.putText(orig, "Label: {}".format(labels[np.argmax(scores)]),
	(10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
# Out:
# array([[[ 63, 120, 166],
#         [ 61, 119, 164],
#         [ 59, 116, 162],
#         ...,
#         [237, 242, 231],
#         [234, 239, 228],
#         [241, 244, 235]],
#
#        [[ 59, 118, 164],
#         [ 62, 119, 165],
#         [ 62, 120, 165],
#         ...,
#         [232, 236, 225],
#         [244, 247, 238],
#         [241, 244, 235]],
#
#        [[ 58, 117, 163],
#         [ 60, 116, 163],
#         [ 62, 117, 165],
#         ...,
#         [245, 249, 239],
#         [249, 253, 243],
#         [246, 251, 241]],
#
#        ...,
#
#        [[105, 186, 237],
#         [103, 186, 234],
#         [103, 184, 234],
#         ...,
#         [ 34,  66,  85],
#         [ 35,  67,  86],
#         [ 34,  67,  85]],
#
#        [[104, 183, 235],
#         [104, 185, 236],
#         [104, 186, 236],
#         ...,
#         [ 38,  70,  89],
#         [ 38,  70,  89],
#         [ 37,  69,  88]],
#
#        [[104, 182, 235],
#         [102, 182, 234],
#         [104, 185, 235],
#         ...,
#         [ 42,  74,  91],
#         [ 40,  72,  91],
#         [ 37,  68,  88]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(orig)
# Out:
# <PIL.Image.Image image mode=RGB size=500x336>
