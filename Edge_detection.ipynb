# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Image-Read/blob/master/Edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
image = cv2.imread("/content/coins01.png")

# %%
image.shape
# Out:
# (308, 350, 3)

# %%
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=350x308>

# %%
gray =cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (308, 350)

# %%
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=350x308>

# %%
wide = cv2.Canny(blurred, 10, 200)
mid = cv2.Canny(blurred, 30, 150)
tight = cv2.Canny(blurred, 240, 250)

# %%
cv2_imshow(wide)
# Out:
# <PIL.Image.Image image mode=L size=350x308>

# %%
cv2_imshow(mid)
# Out:
# <PIL.Image.Image image mode=L size=350x308>

# %%
cv2_imshow(tight)
# Out:
# <PIL.Image.Image image mode=L size=350x308>
